# %%
import lamindb as ln

assert ln.setup.settings.instance.slug == "theislab/sc-best-practices"
ln.track()
# Out:
# → found notebook gsea_pathway.ipynb, making new version
# → created Transform('zTql6b4pzLB30001', key='gsea_pathway.ipynb'), started new Run('1LwwmVoHccwU1lV0') at 2026-07-12 17:44:04 UTC
# → notebook imports: decoupler==2.2.0 lamindb-core==2.7.0 pandas==2.3.3
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("zTql6b4pzLB3")

# %%
import decoupler as dc
import pandas as pd

# %% [markdown]
# Data downloads from Figshare only worked when performed manually via a web browser.
# - 'kang.h5ad': https://figshare.com/ndownloader/files/34464122
# - 'progeny.csv': https://figshare.com/ndownloader/files/38892066

# %% [markdown]
# # 25K PBMC data
# Seems to be exactly the same as key="conditions/differential_gene_expression.h5ad".

# %% [markdown]
# # PROGENy

# %%
progeny = pd.read_csv("progeny.csv")
progeny
# Out:
#         source   target     weight       p_value
# 0     Androgen  TMPRSS2  11.490631  0.000000e+00
# 1     Androgen   NKX3-1  10.622551  2.200000e-44
# 2     Androgen   MBOAT2  10.472733  4.600000e-44
# 3     Androgen     KLK2  10.176186  1.944410e-40
# 4     Androgen     SARG  11.386852  2.790210e-40
# ...        ...      ...        ...           ...
# 1395       p53  CCDC150  -3.174527  7.396252e-13
# 1396       p53    LCE1A   6.154823  8.475458e-13
# 1397       p53    TREM2   4.101937  9.739648e-13
# 1398       p53     GDF9   3.355741  1.087433e-12
# 1399       p53    NHLH2   2.201638  1.651582e-12
#
# [1400 rows x 4 columns]

# %%
af = ln.Artifact.from_dataframe(progeny, key="conditions/gsea_pathway/progeny.parquet")
af
# Out:
# Artifact(uid='n8e4ukVVesVhSUre0000', key='conditions/gsea_pathway/progeny.parquet', description=None, suffix='.parquet', kind='dataset', otype='DataFrame', size=39851, hash='BK48HjL37YxiaQo3qKRP6Q', n_files=None, n_observations=1400, extra_data=None, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=89, schema_id=None, created_by_id=6, created_at=<django.db.models.expressions.DatabaseDefault object at 0x3265f1650>, is_locked=False, version_tag=None, is_latest=True)

# %% [markdown]
# # erygast1k

# %%
adata = dc.ds.erygast1k()
adata
# Out:
# AnnData object with n_obs × n_vars = 801 × 8124
#     obs: 'sample', 'stage', 'sequencing.batch', 'theiler', 'celltype'
#     uns: 'celltype_colors', 'log1p'
#     obsm: 'X_pca', 'X_umap'

# %%
af = ln.Artifact.from_anndata(adata, key="conditions/gsea_pathway/erygast1k.h5ad")
af
# Out:
# Artifact(uid='JS3bMiOOioRrpPVF0000', key='conditions/gsea_pathway/erygast1k.h5ad', description=None, suffix='.h5ad', kind='dataset', otype='AnnData', size=18351616, hash='U4IPNxeZLwINBJgrwxnwzA', n_files=None, n_observations=801, extra_data=None, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=89, schema_id=None, created_by_id=6, created_at=<django.db.models.expressions.DatabaseDefault object at 0x3264efc50>, is_locked=False, version_tag=None, is_latest=True)

# %% [markdown]
# # msvisium

# %%
adata = dc.ds.msvisium()
adata
# Out:
# AnnData object with n_obs × n_vars = 3839 × 14940
#     obs: 'array_row', 'array_col', 'niches'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
af = ln.Artifact.from_anndata(adata, key="conditions/gsea_pathway/msvisium.h5ad")
af
# Out:
# Artifact(uid='ZBHCuQkw65zo86lu0000', key='conditions/gsea_pathway/msvisium.h5ad', description=None, suffix='.h5ad', kind='dataset', otype='AnnData', size=90856207, hash='OzeBmCGAc3Nr-N-pS9stQE', n_files=None, n_observations=3839, extra_data=None, branch_id=1, created_on_id=1, space_id=1, storage_id=1, run_id=89, schema_id=None, created_by_id=6, created_at=<django.db.models.expressions.DatabaseDefault object at 0x3265f2850>, is_locked=False, version_tag=None, is_latest=True)

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor ... ✓
# ! cells [(0, 49)] were not run consecutively
# → finished Run('1LwwmVoHccwU1lV0') after 21s at 2026-07-12 17:44:26 UTC
# → go to: https://lamin.ai/theislab/sc-best-practices/run/1LwwmVoHccwU1lV0
# → to update your notebook from the CLI, run: lamin save /Users/luisheinzlmeier/Desktop/Repos/single-cell-best-practices-parallel/scripts/conditions/gsea_pathway.ipynb
