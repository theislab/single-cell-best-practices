# %% [markdown]
# # Pancreas dataset for 14. RNA velocity

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE132188&format=file&file=GSE132188%5Fadata%2Eh5ad%2Eh5

# %%
import lamindb as ln
import scanpy as sc

assert ln.setup.settings.instance.slug == "theislab/sc-best-practices"

ln.track("aWcFeMqzSw0X")
# Out:
# → loaded Transform('aWcFeMqzSw0X0000', key='rna_velocity_dataset.ipynb'), re-started Run('ceNSq8LFD9vmd6H1') at 2026-02-16 21:12:08 UTC
# → notebook imports: lamindb==2.1.2 scanpy==1.11.5

# %%
adata = sc.read(
    filename="pancreas.h5ad",
    backup_url="https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE132188&format=file&file=GSE132188%5Fadata%2Eh5ad%2Eh5",
)
adata
# Out:
# 100%|██████████| 318M/318M [00:36<00:00, 9.22MB/s]
# /Users/seohyon/miniconda3/envs/rna_velocity/lib/python3.11/site-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# /Users/seohyon/miniconda3/envs/rna_velocity/lib/python3.11/site-packages/anndata/_io/h5ad.py:267: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   return AnnData(**{
# AnnData object with n_obs × n_vars = 36351 × 17327
#     obs: 'day', 'n_counts', 'log_counts', 'n_genes', 'mt_frac', 'proliferation', 'G2M_score', 'S_score', 'clusters_fig3_final', 'clusters_fig3_final_noep', 'clusters_fig4_final', 'clusters_fig2_final', 'clusters_fig6_broad_final', 'clusters_fig6_fine_final', 'clusters_fig6_alpha_final'
# ...

# %%
af = ln.Artifact(
    "pancreas.h5ad",
    key="trajectory/rna_velocity.h5ad",
    description="Pancreas dataset for RNA velocity",
).save()
af
# Out:
# ... uploading pancreas.h5ad: 100.0%
# Artifact(uid='OQ9LKW6DkUQYMF8v0000', version_tag=None, is_latest=True, key='trajectory/rna_velocity.h5ad', description='Pancreas dataset for RNA velocity', suffix='.h5ad', kind=None, otype='AnnData', size=333642690, hash='jxhpZGo-Sa3bXsj9XRkREc', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=41, schema_id=None, created_by_id=5, created_at=2026-02-16 21:14:48 UTC, is_locked=False)
