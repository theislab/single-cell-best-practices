# %% [markdown]
# # Reference embedding h5ad for 11. Annotation

# %% [markdown]
# https://figshare.com/ndownloader/files/41376264

# %%
import lamindb as ln
# Out:
# → connected lamindb: theislab/sc-best-practices

# %%
ln.track("fYSEh5kJ5gI8")
# Out:
# → loaded Transform('fYSEh5kJ5gI80000', key='annotation_reference_embedding.ipynb'), re-started Run('IijRqMgeAPkBKP1c') at 2026-02-16 17:45:00 UTC
# → notebook imports: lamindb==2.0.1 scanpy==1.11.1

# %%
af = ln.Artifact(
    "/Users/seohyon/Downloads/reference_embedding.h5ad",
    key="cellular_structure/annotation_reference_embedding.h5ad",
    description="Reference model",
).save()
af
# Out:
# ... uploading reference_embedding.h5ad: 100.0%
# Artifact(uid='4IZPEBYHhaws32ta0000', version_tag=None, is_latest=True, key='cellular_structure/annotation_reference_embedding.h5ad', description='Reference model', suffix='.h5ad', kind=None, otype='AnnData', size=38845904, hash='9yLSrQ3C9DG712jRtEqtRA', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=40, schema_id=None, created_by_id=5, created_at=2026-02-16 17:45:09 UTC, is_locked=False)
