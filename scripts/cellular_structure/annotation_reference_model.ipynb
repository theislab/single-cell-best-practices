# %% [markdown]
# # Reference model for 10. Annotation

# %% [markdown]
# https://figshare.com/ndownloader/files/41436648

# %%
import lamindb as ln
# Out:
# → connected lamindb: theislab/sc-best-practices

# %%
ln.track("Gy0XSuExgx5c")
# Out:
# → loaded Transform('Gy0XSuExgx5c0000', key='annotation_reference_model.ipynb'), re-started Run('dyWEiPXL8amdumfh') at 2026-02-16 16:38:40 UTC
# → notebook imports: lamindb==2.0.1 scanpy==1.11.1

# %%
af = ln.Artifact(
    "/Users/seohyon/Downloads/model.pt",
    key="cellular_structure/annotation_reference_model.pt",
    description="Reference model",
).save()
af
# Out:
# → returning artifact with same hash: Artifact(uid='QbA3dlfKrj435HXb0000', version_tag=None, is_latest=True, key='cellular_structure/annotation_reference_model.pt', description='Reference model', suffix='.pt', kind=None, otype=None, size=11404250, hash='Nw991J5Ll76HLOcJ8cLO5A', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=None, schema_id=None, created_by_id=5, created_at=2026-02-16 16:37:56 UTC, is_locked=False); to track this artifact as an input, use: ln.Artifact.get()
# ! run was not set on Artifact(uid='QbA3dlfKrj435HXb0000', version_tag=None, is_latest=True, key='cellular_structure/annotation_reference_model.pt', description='Reference model', suffix='.pt', kind=None, otype=None, size=11404250, hash='Nw991J5Ll76HLOcJ8cLO5A', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=None, schema_id=None, created_by_id=5, created_at=2026-02-16 16:37:56 UTC, is_locked=False), setting to current run
# ...
