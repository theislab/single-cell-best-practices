# %% [markdown]
# # Integration dataset

# %%
import lamindb as ln
import scanpy as sc
# Out:
# → connected lamindb: theislab/sc-best-practices

# %%
assert ln.setup.settings.instance.slug == "theislab/sc-best-practices"

# %%
ln.__version__
# Out:
# '2.0a2'

# %%
ln.track()
# Out:
# → created Transform('4ca7y0XH5g1A0000', key='integration_dataset.ipynb'), started new Run('kJSBNH9i7xh5hhJ8') at 2026-01-14 00:04:36 UTC
# → notebook imports: lamindb==2.0a2 scanpy==1.11.1
# • recommendation: to identify the notebook across renames, pass the uid: ln.track("4ca7y0XH5g1A")

# %%
adata = sc.read(
    filename="openproblems_bmmc_multiome_genes_filtered.h5ad",
    backup_url="https://figshare.com/ndownloader/files/45452260",
)
adata
# Out:
#   0%|          | 0.00/2.90G [00:00<?, ?B/s]
# AnnData object with n_obs × n_vars = 69249 × 129921
#     obs: 'GEX_pct_counts_mt', 'GEX_n_counts', 'GEX_n_genes', 'GEX_size_factors', 'GEX_phase', 'ATAC_nCount_peaks', 'ATAC_atac_fragments', 'ATAC_reads_in_peaks_frac', 'ATAC_blacklist_fraction', 'ATAC_nucleosome_signal', 'cell_type', 'batch', 'ATAC_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker'
#     var: 'feature_types', 'gene_id'
#     uns: 'ATAC_gene_activity_var_names', 'dataset_id', 'genome', 'organism'
#     obsm: 'ATAC_gene_activity', 'ATAC_lsi_full', 'ATAC_lsi_red', 'ATAC_umap', 'GEX_X_pca', 'GEX_X_umap'
#     layers: 'counts'

# %%
af = ln.Artifact(
    "openproblems_bmmc_multiome_genes_filtered.h5ad",
    key="cellular_structure/openproblems_bmmc_multiome_genes_filtered.h5ad",
    description="cellular structure integration dataset",
).save()
af
# Out:
# ... uploading openproblems_bmmc_multiome_genes_filtered.h5ad: 100.0%
# Artifact(uid='4wQy06nqwb3Pjf1m0000', version_tag=None, is_latest=True, key='cellular_structure/openproblems_bmmc_multiome_genes_filtered.h5ad', description='cellular structure integration dataset', suffix='.h5ad', kind=None, otype='AnnData', size=3116868580, hash='-r4RRe282-drQ5-EU5w_6X', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=30, schema_id=None, created_by_id=5, created_at=2026-01-14 00:10:10 UTC, is_locked=False)

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor .... still waiting . ✓
# → finished Run('kJSBNH9i7xh5hhJ8') after 15m at 2026-01-14 00:19:43 UTC
# → go to: https://lamin.ai/theislab/sc-best-practices/transform/4ca7y0XH5g1A0000
# → to update your notebook from the CLI, run: lamin save /Users/seohyon/seocodes/single-cell-best-practices/scripts/cellular_structure/integration_dataset.ipynb
