# %% [markdown]
# # Annotation reference model's feature information

# %%
import lamindb as ln
# Out:
# → connected lamindb: theislab/sc-best-practices

# %%
assert ln.setup.settings.instance.slug == "theislab/sc-best-practices"

# %%
ln.track("OzNvWY5Jj0ao")
# Out:
# → loaded Transform('OzNvWY5Jj0ao0000', key='annotation_reference_table.ipynb'), re-started Run('SRwHHiDGVSiTCzVd') at 2026-01-23 17:16:18 UTC
# → notebook imports: lamindb==2.0.1 scanpy==1.11.1

# %%
af = ln.Artifact.from_dataframe(
    "/Users/seohyon/Downloads/gene_info.csv",
    key="cellular_structure/annotation_reference_features.csv",
    description="Reference model features for scArches mapping",
).save()
af
# Out:
# → returning artifact with same hash: Artifact(uid='Nk8E7I1szcOp75GB0000', version_tag=None, is_latest=True, key='cellular_structure/annotation_reference_features.csv', description='Reference model features for scArches mapping', suffix='.csv', kind=None, otype='DataFrame', size=93163, hash='6v_l29rLvHW0R4Gh7fAPUA', n_files=None, n_observations=None, branch_id=1, space_id=1, storage_id=1, run_id=35, schema_id=None, created_by_id=5, created_at=2026-01-23 17:16:21 UTC, is_locked=False); to track this artifact as an input, use: ln.Artifact.get()
# ...

# %%
ln.finish()
# Out:
# • please hit CMD + s to save the notebook in your editor .. ✓
# ! cells [(2, 5), (5, 7)] were not run consecutively
# → finished Run('SRwHHiDGVSiTCzVd') after 42s at 2026-01-23 17:17:00 UTC
# → go to: https://lamin.ai/theislab/sc-best-practices/transform/OzNvWY5Jj0ao0000
# → to update your notebook from the CLI, run: lamin save /Users/seohyon/seocodes/single-cell-best-practices/scripts/cellular_structure/annotation_reference_table.ipynb
